# %% [markdown]
# # **Семинар 1-2. Введение в инструменты. Библиотеки Pandas и Numpy**

# %% [markdown]
# ## **Датафреймы. Библиотека** `Pandas`

# %% [markdown]
# Pandas - библиотека для работы с табличными данными в питоне.

# %%
# !pip install pandas

# %%
import pandas as pd # импортировали библиотеку pandas и назвали ее pd

# %% [markdown]
# ### Создание собственного датафрейма

# %%
df = pd.DataFrame() # создаем пустой датафрейм
#df.index = ['A', 'B', 'C']
df["c"] = [10,20,30]
df["a"] = ['one', 12, 13]
df["A"] = [1, 12, 13]
df                  # выводим датафрейм
# Out:
#     c    a   A
# 0  10  one   1
# 1  20   12  12
# 2  30   13  13

# %%
|'one'
'12'
'13'
str>float>int

[1.0, 2, 3]
1.0
2.0
3.0

# %% [markdown]
# ### Работа с готовыми таблицами

# %% [markdown]
# #### Считывание таблицы

# %% [markdown]
# Конечно, чаще всего приходится работать с уже готовыми наборами данных. Такие данные обычно хранятся в формтае xls(x) - для работы в Excel, или (чаще) в формате csv - comma-separated value. Попробуем импортировать csv файл с данными о пассажирах Титаника: они лежат в файле 'titanic.csv' (попродуйте открыть его в текстовом редакторе и посмотрите, как он устроен внутри).

# %%
# import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/rogovich/Data/master/data/titanic/train.csv')

# %% [markdown]
# Функция `read_csv` читает данные из файла формата *csv* данные и преобразует в pandas.DataFrame.
#
# Аналогичная функция `read_excel` может читать данные в офрмате *xls(x)*.

# %% [markdown]
# #### Просмотр датафрейма

# %% [markdown]
# Посмотреть весь датафрейм

# %% [markdown]
# ```
# название датафрейма
# ```

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Посмотреть первые строки датафрейма с помощью функции `head()`. По умолчанию 5
#
#
#
# ```
# название датафрейма.head()
# ```

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.head(2) # можно передать аргументом количество строк, которые хотите увидеть
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# Посмотреть последние строки датафрейма с помощью функции `tail()`. По умолчанию 5
#
#
#
# ```
# название датафрейма.tail()
# ```

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.tail(11) # можно передать аргументом количество строк, которые хотите увидеть
# Out:
#      PassengerId  Survived  Pclass  \
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 881                            Markun, Mr. Johann    male  33.0      0      0
# 882                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 883                 Banfield, Mr. Frederick James    male  28.0      0      0
# 884                        Sutehall, Mr. Henry Jr    male  25.0      0      0
# ...

# %% [markdown]
# ### Базовая информация про датафрейм

# %% [markdown]
# ```
# датафрейм.info()
# ```

# %% [markdown]
# #### Основная информация `.info()`

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #### Формат данных `.dtypes`

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
объект.метод()
объект.свойство
функция(объект)

# %% [markdown]
# #### Размер датафрейма `.shape`

# %% [markdown]
# ```
# датафрейм.shape
# ```

# %%
data.shape[0]#(строк, столбцов)
# Out:
# 891

# %% [markdown]
# #### Название колонок `.columns`

# %% [markdown]
# ```
# название датафрейма.columns
# ```

# %%
data.columns # список столбцов
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Обращение к элементам датафрейма

# %% [markdown]
# Описание признаков:
#
# **PassengerId** - id пассажира
#
# **Survived** бинарная переменная: выжил пассажирил (1) или нет (0)
#
# **Pclass** - класс пассажира
#
# **Name** - имя пассажира
#
# **Sex** - пол пассажира
#
# **Age** - возраст пассажира
#
# **SibSp** - количество родственников (братьев, сестер, супругов) пассажира на борту
#
# **Parch** - количество родственников (родителей / детей) пассажира на борту
#
# **Ticket** - номер билета
#
# **Fare** - тариф (стоимость билета)
#
# **Cabin** - номер кабины
#
# **Embarked** - порт, в котором пассажир сел на борт (C - Cherbourg, S - Southampton, Q = Queenstown)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Обращение к столбцу

# %% [markdown]
# ```
# датафрейм[столбец]
# ```
# или
#
# ```
# датафрейм.столбец
# ```

# %%
data #обращаемся к датафрейму

# %%
data["Age"] #обращаемся к колонке
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# #### Обращение нескольким столбцам

# %% [markdown]
# ```
# датафрейм[[столбец 1, столбец 2, ...]]
# ```

# %%
columns_to_show = ['Age', 'Sex', 'Pclass']
data[columns_to_show]
# Out:
#       Age     Sex  Pclass
# 0    22.0    male       3
# 1    38.0  female       1
# 2    26.0  female       3
# 3    35.0  female       1
# 4    35.0    male       3
# ..    ...     ...     ...
# 886  27.0    male       2
# 887  19.0  female       1
# 888   NaN  female       3
# 889  26.0    male       1
# 890  32.0    male       3
#
# [891 rows x 3 columns]

# %% [markdown]
# #### Обращение к строке

# %% [markdown]
# ```
# датафрейм.loc[индекс]
# ```
# или
# ```
# датафрейм.iloc[положение]
# ```

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
data.loc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data.loc[0, 'Name']#['Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %% [markdown]
# `loc` возвращает данные на основе индекса, а `iloc` - основываясь исключительно на позиции индекса, начиная с 0

# %% [markdown]
# ## **Типы данных**

# %% [markdown]
# ![типыданных.png](data:image/png;base64,...)

# %% [markdown]
# **Числовые**
# *   *Непрерывные*: рост людей, заработная плата
# *   *Дискретные*: количество детей, количество команд в турнире, количество лет образования
#
# **Категориальные**
# *   *Порядковые*: оценки студентов (A, B, C...), уровень образования, уровень зарплаты
# *   *Номинальные*: пол, цвет глаз, семейное положение

# %% [markdown]
# ## **Фильтрация данных**

# %% [markdown]
# ### Одно условие

# %% [markdown]
# #### `==`

# %%
data[data['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_female = data[data['Sex'] == 'female']

# %%
data[data['Sex'] == 'female'].iloc[4]
# Out:
# PassengerId                                     10
# Survived                                         1
# Pclass                                           2
# Name           Nasser, Mrs. Nicholas (Adele Achem)
# Sex                                         female
# Age                                           14.0
# SibSp                                            1
# Parch                                            0
# Ticket                                      237736
# Fare                                       30.0708
# Cabin                                          NaN
# Embarked                                         C
# Name: 9, dtype: object

# %% [markdown]
# #### `<`/>/`<=`/`>=`

# %%
data[data['Age'] < 18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %% [markdown]
# #### Несколько условий

# %%
| - или
& - и

# %%
data[(data['Sex'] == 'female') | (data['Age'] > 18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[(data['Sex'] == 'female') | (data['Age'] > 18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[data['Pclass'].isin([1, 2])] # data[(data['Pclass'] == 1) | (data['Pclass'] == 2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Подсчет количества наблюдений после фильтрации `.shape`

# %%
data[(data['Sex'] == 'female') & (data['Age'] > 18)].shape[0]
# Out:
# 193

# %% [markdown]
# Как извлечь только количество наблюдений, без количества столбцов?

# %% [markdown]
# ## **Сортировка данных** `.sort_values()`

# %%
data.sort_values('Age') # сортируем по возрасту, по умолчанию сортирвка по возрастанию
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data.sort_values('Age', ascending=False) # сортируем по возрасту, теперь по убыванию
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data.sort_values(['Age', 'Fare'], ascending=False)[['Age', 'Fare']] # сортируем сперва (по убыванию),
                                                             # потом по стоимости билета  (по убыванию)
# Out:
#       Age     Fare
# 630  80.0  30.0000
# 851  74.0   7.7750
# 493  71.0  49.5042
# 96   71.0  34.6542
# 116  70.5   7.7500
# ..    ...      ...
# 481   NaN   0.0000
# 633   NaN   0.0000
# 674   NaN   0.0000
# 732   NaN   0.0000
# 815   NaN   0.0000
#
# [891 rows x 2 columns]

# %%
data.sort_values(['Age', 'Fare'], ascending=[False, True])[['Age', 'Fare']] # сортируем сперва возраст (по убыванию),
                                                                     # потом по стоимости билета  (по возрастанию)
# Out:
#       Age      Fare
# 630  80.0   30.0000
# 851  74.0    7.7750
# 96   71.0   34.6542
# 493  71.0   49.5042
# 116  70.5    7.7500
# ..    ...       ...
# 306   NaN  110.8833
# 334   NaN  133.6500
# 31    NaN  146.5208
# 527   NaN  221.7792
# 557   NaN  227.5250
#
# [891 rows x 2 columns]

# %% [markdown]
# ## **Новый признак**

# %% [markdown]
# Иногда нужно создать новый признак из уже существующих, например, нам интересно, сколько всего родственников путешествовало с каждым пассажиром - просто сложим столбцы `SibSp` и `Parch` и поместим сумму в новый столбец `FamilySize`.

# %%
data['FamilySize'] = data['SibSp'] + data['Parch']
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# ...

# %% [markdown]
# ### Анонимные функции (`lambda` функции)

# %% [markdown]
# Это же можно реализовать короче с помощью анонимных функций.
#
# Это особый вид функций, которые объявляются с помощью ключевого слова `lambda` вместо `def`:
#
#     lambda x: инструкция

# %% [markdown]
# Применить функцию можно с помощью метода `.apply()`

# %% [markdown]
# Создадим столбец `Alone` на основе признака `FamilySize`, определяет ехал человек в одиночку (**True**) или с родствениками (**False**):

# %%
import numpy as np

# %%
data['Alone'] = data['FamilySize'].apply(lambda x: True if x == 0 else False)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  Alone
# 0      0         A/5 21171   7.2500   NaN        S           1  False
# 1      0          PC 17599  71.2833   C85        C           1  False
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0   True
# ...

# %%
data['sqrtAge'] = data['Age'].apply(np.sqrt)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Функции

# %% [markdown]
# Можно использовать обычную функцию, которую мы создаем при помощи `def`:
#
# ```
# def name(x):
#   if условие 1:
#      return результат
#   elif условие 2:
#      return результат
#   ...
#   else:
#      return результат
# ```

# %% [markdown]
# Создаем функцию `clss`, которая перекодирует признак `Pclass` следущим образом:
# - *1 класс*  - **High**
# - *2 класс* - **Middle**
# - *3 класс* - **Low**

# %%
def clss(x):
  if x == 1:
    return 'High'
  elif x == 2:
   return 'Middle'
  else:
    return 'Low'

# %% [markdown]
# Теперь создаем новую колонку `Pclass_coded`, куда запишем результат работы нашей функции класс `clss`:

# %%
data['Pclass_coded'] = data['Pclass'].apply(clss)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  Alone  \
# 0      0         A/5 21171   7.2500   NaN        S           1  False
# 1      0          PC 17599  71.2833   C85        C           1  False
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0   True
# ...

# %% [markdown]
# ## **Удаление повторений** `.drop_duplicates()`

# %%
df1 = pd.DataFrame()
df1["Продукты"] = ["Яблоки", "Бананы", "Морковка", "Огурец", "Яблоки", "Томат", "Яблоки"]
df1["Цвет"] = ["Красный", "Желтый", "Оранжевый", "Зеленый", "Зеленый", "Красный", "Зеленый"]
df1
# Out:
#    Продукты       Цвет
# 0    Яблоки    Красный
# 1    Бананы     Желтый
# 2  Морковка  Оранжевый
# 3    Огурец    Зеленый
# 4    Яблоки    Зеленый
# 5     Томат    Красный
# 6    Яблоки    Зеленый

# %%
df2 = df1.drop_duplicates('Продукты')

# %%
df2
# Out:
#    Продукты       Цвет
# 0    Яблоки    Красный
# 1    Бананы     Желтый
# 2  Морковка  Оранжевый
# 3    Огурец    Зеленый
# 5     Томат    Красный

# %%
df1.drop_duplicates(['Продукты', 'Цвет'])
# Out:
#    Продукты       Цвет
# 0    Яблоки    Красный
# 1    Бананы     Желтый
# 2  Морковка  Оранжевый
# 3    Огурец    Зеленый
# 4    Яблоки    Зеленый
# 5     Томат    Красный

# %% [markdown]
# ## **Массивы. Библиотека** `Numpy`

# %%
[1, 3] + [3, 4] = [1, 3, 3, 4]

# %%
[1, 3] + [3, 4]
# Out:
# [1, 3, 3, 4]

# %%
[1]*5
# Out:
# [1, 1, 1, 1, 1]

# %%
import numpy as np

# %%
np.array([1, 3]) + np.array([3, 4])
# Out:
# array([4, 7])

# %%
np.sqrt(data['Age'])
# Out:
# 0      4.690416
# 1      6.164414
# 2      5.099020
# 3      5.916080
# 4      5.916080
#          ...
# 886    5.196152
# 887    4.358899
# 888         NaN
# 889    5.099020
# 890    5.656854
# Name: Age, Length: 891, dtype: float64

# %%
array([2, 1]) + array([3, 1]) = array([5, 2])

# %%
a = np.array([1, 3]) + np.array([3, 4])

# %%
a.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Массивы

# %% [markdown]
# **Массив** - упорядоченная изменяемая структура данных к элементам которого можно обратиться по индексу/ам
#
# Массив может:
#
# *   хранить неуникальные элементы
# *   хранить ТОЛЬКО элементы одного типа (int/float/str/bool)
#
#
# > Сила типов данных:
# >> `str>float>int>bool`
#
# Почему массив это удобно:
#
# *   они занимают меньше места и памяти
# *   все операции над массивами будут производиться поэлементно: то есть, для выполнения действий над каждым элементом массива, нам не придется использовать какие-то специальные конструкции вроде циклов, мы сможем обращаться сразу ко всему массиву
# *   вычислительные операции быстрее выполняются с массивами numpy чем со списками

# %%
True, 12
1, 12

# %% [markdown]
# ### Создание массива

# %% [markdown]
# Массив можно создать с помощью библиотеки ```NumPy```(сокращение от Numeric Python), которую нужно для начала импортировать в блокнот (если библиотека не импортируется проверьте, что она установлена на ваш компьютер)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Способ 1**
#
# Создание массива происходит с помощью встроенной в библиотеку `NumPy` функции `array()`

# %% [markdown]
# ```
# np.array(данные, тип данных)
# ```
#
# `тип данных` необязательный аргумент

# %%
np.array([0, 1, 2, 3])
# Out:
# array([0, 1, 2, 3])

# %%
np.array([0, 1, 2, 3], float)
# Out:
# array([0., 1., 2., 3.])

# %% [markdown]
# **Способ 2**
#
# Можно создать массив на основе промежутка, созданного с помощью `arange()` – функции `numpy`, похожей на стандартный `range()`, только более гибкую. Посмотрим, как работает эта функция.

# %% [markdown]
# ```
# np.arange(начало диапазона (включительно), конец диапазона(невключительно), шаг)
# ```

# %%
range(5) -> 0, 1, 2, 3, 4
range(1, 5) -> 1, 2, 3, 4
range(1, 5, 2) -> 1, 3

# %%
from numpy import *

# %%
np.arange(2, 9) # по умолчанию шаг равен 1, как обычный range()
# Out:
# array([2, 3, 4, 5, 6, 7, 8])

# %%
np.arange(2, 9, 3) # с шагом 3
# Out:
# array([2, 5, 8])

# %% [markdown]
# ### Типы массивов

# %% [markdown]
# Массивы бывают:
# *   одномерные
# *   многомерные (n-мерные)

# %% [markdown]
# Одномерные:

# %%
np.array([0, 1, 2, 3])
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# ![Снимок экрана 2022-09-06 в 18.31.20.png](data:image/png;base64,...)

# %% [markdown]
# Многомерные:

# %% [markdown]
# ```
# [[список 1], [список 2], [список 3]] #двумерный массив
# ```

# %%
np.array([[0, 1],
          [2, 3]]) #двумерные
# Out:
# array([[0, 1],
#        [2, 3]])

# %%
# Out:
# 0

# %% [markdown]
# ![Снимок экрана 2022-09-06 в 18.34.25.png](data:image/png;base64,...)

# %% [markdown]
# ```
# [[[список 1], [список 2]], [[список 3], [список 4]]] #трехмерный массив
#
# ```

# %%
x = np.array([[[0, 1],[2, 3]],
              [[4, 5],[6, 7]]]) # трехмерный

# %%
x[0][0][1]
# Out:
# 1

# %% [markdown]
# ![Снимок экрана 2022-09-06 в 18.48.03.png](data:image/png;base64,...)

# %% [markdown]
# ### Работа с элементами массива

# %% [markdown]
# Если нам нужно обратиться к элементам массива, то эта операция будет похожа на работу со вложенными списками:

# %%
import numpy as np
M = np.array([[0, 1],
              [2, 3],
              [4, 5]])
M
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
M[0][0]
# Out:
# 0

# %%
M[0,0]
# Out:
# 0

# %% [markdown]
# ```
# массив[строка][столбец]
# ```

# %% [markdown]
# ![Снимок экрана 2022-09-08 в 13.46.47.png](data:image/png;base64,...)

# %%
M[0]  # весь первый список в M
# Out:
# array([0, 1])

# %%
M[1][1]  # второй элемент первого списка в M
# Out:
# 3

# %%
M
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
M[:, 1]
# Out:
# array([1, 3, 5])

# %% [markdown]
# Ещё можно выбирать сразу несколько элементов массива. Для этого воспользуемся срезами (*slices*):

# %%
M[0:2]  # с элемента с индексом 0 до элемента с индексом 1 включительно
# Out:
# array([[0, 1],
#        [2, 3]])

# %% [markdown]
# Обратите внимание: правый конец среза не включается.

# %% [markdown]
# Концы среза можно опускать, если нас интересуют все элементы, начиная с некоторого элемента и до конца массива или начиная с первого элемента массива и до некоторого элемента (правый конец точно так же включаться не будет):

# %%
M[1:] # с элемента с индексом 1 до конца
# Out:
# array([[2, 3],
#        [4, 5]])

# %%
M[:2] # с начала массива до элемента с индексом 1 включительно
# Out:
# array([[0, 1],
#        [2, 3]])

# %% [markdown]
# Кроме того, при выборе элементов можно выставлять шаг. По умолчанию мы выбираем все элементы подряд, шаг равен 1, но это можно изменить:

# %%
M[0:3]  # с нулевого по третий через 2
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %% [markdown]
# Или сделать более интересную вещь, взять отрицательный шаг и выбрать все элементы в обратном порядке, с конца:

# %%
M[::-1]
# Out:
# array([[4, 5],
#        [2, 3],
#        [0, 1]])

# %% [markdown]
# А самое ценное, что можно обращаться к элементам не только по рядам, но и по колонкам с помощью индексации через запятую

# %%
M[:, 1] # только второй элемент из каждого ряда (:)
# Out:
# array([1, 3, 5])

# %%
M[1][1]
# Out:
# 3

# %%
M[1,1]
# Out:
# 3

# %%
M[1:, 1] # первый элемент для каждого ряда, начиная со второго
# Out:
# array([3, 5])

# %% [markdown]
# ### Характеристики массива

# %%
M = np.array([[0, 1],
              [2, 3],
              [4, 5]])
M
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %% [markdown]
# Количество столбцов в массиве (матрице) `ndim`:

# %%
M.ndim # dimensions
# Out:
# 2

# %% [markdown]
# Форма или вид массива `shape`:

# %%
M.shape  # 3 строки и 2 столбца, т.е. 3 списка по 2 элемента
# Out:
# (3, 2)

# %% [markdown]
# Количество элементов в массиве `size`:

# %%
M.size  # всего 6 элементов
# Out:
# 6

# %% [markdown]
# Тип данных, хранящихся в массиве `dtype`:

# %%
M.dtype
# Out:
# dtype('int64')

# %% [markdown]
# В `numpy` имеются все питоновские типы, а также обёртки над этими типами, которые **используют реализацию типов на C**, например, `int8`, `int16`, `int32`, `int64` (подробнее о типах данных `numpy` можно прочитать [здесь](https://www.numpy.org/devdocs/user/basics.types.html)). За счёт того, что используются типы данных из C, numpy получает ускорение операций.

# %% [markdown]
# ### Базовые операции с массивами

# %%
a = np.array([0.1, 0.2, 0.3, 0.4])
a*100
# Out:
# array([10., 20., 30., 40.])

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

a+b
# Out:
# array([5, 7, 9])

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
с = np.array([7, 8, 9])

(a + b)/с
# Out:
# array([0.71428571, 0.875     , 1.        ])

# %% [markdown]
# Минимум и максимум:
#
#
#
# ```
# массив.min()
# ```
#
# ```
# массив.max()
# ```

# %%
a = np.array([1, 2, 3])
a.min()
# Out:
# 1

# %%
a = np.array([1, 2, 3])
a.max()
# Out:
# 3

# %%
np.max(a)
# Out:
# 3

# %% [markdown]
# Среднее:
#
#
#
# ```
# массив.mean()
# ```

# %%
a = np.array([1, 2, 3])
a.mean()
# Out:
# 2.0

# %% [markdown]
# Медиана
#
#
#
# ```
# np.median(массив)
# ```

# %%
a = np.array([1, 2, 3])
np.median(a)
# Out:
# 2.0

# %% [markdown]
# Вернуть

# %% [markdown]
# ### Произведение векторов

# %% [markdown]
# #### Скалярное произведение векторов

# %% [markdown]
# ![Снимок экрана 2022-09-06 в 19.26.27.png](data:image/png;base64,...)

# %%
a = np.array([0, 1, 2])
b = np.array([3, 4, 5])
print(a @ b)    # python 3 style
#print(a.dot(b))
#print(np.dot(a, b))
# Out:
# 14

# %% [markdown]
# #### Скалярное произведение матриц

# %% [markdown]
# **Умножить можно только такие матрицы, в которых число столбцов первой матрицы равно числу строк второй**

# %% [markdown]
# ![Снимок экрана 2022-09-06 в 19.22.23.png](data:image/png;base64,...)

# %%
a = np.array([[0, 1], [2, 3]])
b = np.array([[4,5], [6, 7]])


print(a @ b)
#print(a.dot(b))
#print(np.dot(a, b))

# %% [markdown]
# ![Снимок экрана 2022-09-06 в 19.50.45.png](data:image/png;base64,...)

# %%
a = np.array([[0, 1], [2, 3]])
b = np.array([[4,5], [6, 7], [8, 9]])
print(a @ b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-2e9093a72324> in <cell line: 3>()
#       1 a = np.array([[0, 1], [2, 3]])
#       2 b = np.array([[4,5], [6, 7], [8, 9]])
# ----> 3 print(a @ b)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 2)

# %% [markdown]
# ![Снимок экрана 2022-09-06 в 20.00.49.png](data:image/png;base64,...)

# %%
a = np.array([[0, 1], [2, 3]])
b = np.array([[4,5,6], [7, 8, 9]])
print(a @ b)
# Out:
# [[ 7  8  9]
#  [29 34 39]]

# %% [markdown]
# #### Скалярное произведение матрицы и векторов

# %% [markdown]
# ![Снимок экрана 2022-09-06 в 19.45.46.png](data:image/png;base64,...)

# %%
C = np.array([[0, 1], [2, 3]])
b = np.array([4,5])
print(a @ b)
# Out:
# [ 5 23]

# %%
print(a.shape)
print(b.shape)
# Out:
# (2, 2)
# (2,)

# %% [markdown]
# #### Координатное произведение

# %% [markdown]
# ![Снимок экрана 2022-09-06 в 20.05.08.png](data:image/png;base64,...)

# %%
a = np.array([[0, 1], [2, 3]])
b = np.array([[4,5], [6, 7]])
print(a * b)
# Out:
# [[ 0  5]
#  [12 21]]
